# %%
import pandas as pd
import numpy as np
import sqlite3
import matplotlib.pyplot as plt

connection_string = sqlite3.connect("sales_data_final.db")
query = "select * from sales_data limit 5"
df = pd.read_sql_query(query, connection_string)
print(df)
# Out:
#    customer_id customer_name     location order_date product_name  \
# 0            1   Customer 59  Los Angeles   21-07-22        Dress
# 1            2   Customer 10      Houston   21-01-22   Smartphone
# 2            3   Customer 59     New York   20-07-22        Pants
# 3            4   Customer 23      Houston   10-01-22        Dress
# 4            5   Customer 26      Chicago   22-10-22     Textbook
#
#       category  quantity   price
# 0     Clothing         1   80.76
# 1  Electronics         4  153.69
# 2     Clothing         1   71.02
# 3     Clothing         1   52.14
# 4        Books         3   15.25

# %%
import pandas as pd
import numpy as np
import sqlite3
import matplotlib.pyplot as plt

connection_string = sqlite3.connect("sales_data_final.db")
query = "select product_name, SUM(quantity) as 'total_quantity',SUM(quantity * price) as 'revenue'  from sales_data group by product_name order by revenue desc"
products_by_revenue = pd.read_sql_query(query, connection_string)
print(products_by_revenue)
# Out:
#      product_name  total_quantity   revenue
# 0      Headphones             198  19616.54
# 1        Cookbook             170  19139.80
# 2        Textbook             142  16059.67
# 3         Perfume             151  15259.45
# 4        Lipstick             130  14768.92
# 5           Shoes             148  14213.55
# 6    Cookware Set             122  13230.92
# 7      Wall Decor             110  13168.04
# 8    Dining Table             133  12957.92
# 9       Biography             114  12955.84
# 10  Children Book             105  12558.65
# 11    Nail Polish             115  12552.40
# 12  Fiction Novel             110  11974.67
# 13         Laptop             123  11910.44
# 14     Smartphone             110  11888.96
# 15          Pants             108  11788.52
# 16     Hair Dryer             121  11704.67
# 17     Bed Sheets             124  11587.46
# 18         Jacket             106  11036.47
# 19         Tablet              98  10828.45
# ...

# %%
plt = products_by_revenue.plot(kind='bar',x='product_name',y='revenue')
plt.set_xlabel("Product")
plt.set_ylabel("Revenue")
plt.set_title("Revenue by Product")
# Out:
# Text(0.5, 1.0, 'Revenue by Product')

# %%
import pandas as pd
import numpy as np
import sqlite3
import matplotlib.pyplot as plt

connection_string = sqlite3.connect("sales_data_final.db")
query = "select product_name, SUM(quantity) as 'total_quantity',SUM(quantity * price) as 'revenue'  from sales_data group by product_name order by revenue desc limit 5"
df = pd.read_sql_query(query, connection_string)
print(df)
# Out:
#   product_name  total_quantity   revenue
# 0   Headphones             198  19616.54
# 1     Cookbook             170  19139.80
# 2     Textbook             142  16059.67
# 3      Perfume             151  15259.45
# 4     Lipstick             130  14768.92

# %%
plt = df.plot(kind='bar',x='product_name',y='revenue')
plt.set_xlabel("Product")
plt.set_ylabel("Revenue")
plt.set_title("Top 5 Products by revenue")
# Out:
# Text(0.5, 1.0, 'Top 5 Products by revenue')

# %%
import pandas as pd
import numpy as np
import sqlite3
import matplotlib.pyplot as plt

connection_string = sqlite3.connect("sales_data_final.db")

query = "select category, SUM(quantity) as 'total_quantity',SUM(quantity * price) as 'revenue' from sales_data group by category order by revenue desc"
category_wise_revenue = pd.read_sql_query(query, connection_string)
print(category_wise_revenue)
# Out:
#          category  total_quantity   revenue
# 0           Books             641  72688.63
# 1     Electronics             638  64964.54
# 2          Beauty             625  63563.65
# 3  Home & Kitchen             594  61188.98
# 4        Clothing             569  58242.28

# %%
plt = category_wise_revenue.plot(kind='bar',x='category',y='revenue')
plt.set_xlabel("Category")
plt.set_ylabel("Revenue")
plt.set_title("Revenue by Category")
# Out:
# Text(0.5, 1.0, 'Revenue by Category')

# %%
import pandas as pd
import numpy as np
import sqlite3
import matplotlib.pyplot as plt


connection_string = sqlite3.connect("sales_data_final.db")
query = "select location ,product_name, SUM(quantity) as 'total_quantity',SUM(quantity * price) as 'revenue'  from sales_data group by location order by revenue desc"
location_wise_revenue = pd.read_sql_query(query, connection_string)
print(location_wise_revenue)
# Out:
#       location product_name  total_quantity   revenue
# 0      Phoenix        Shirt             648  71060.89
# 1      Houston   Smartphone             653  70070.06
# 2     New York        Pants             590  61926.57
# 3      Chicago     Textbook             605  60443.55
# 4  Los Angeles        Dress             571  57147.01

# %%
plt = location_wise_revenue.plot(kind="bar", x="location", y="revenue")
plt.set_xlabel("Location")
plt.set_ylabel("Revenue")
plt.set_title("Revenue by location")
# Out:
# Text(0.5, 1.0, 'Revenue by location')
